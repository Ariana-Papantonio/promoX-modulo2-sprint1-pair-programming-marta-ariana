# %% [markdown]
# ## Pair programming Python + SQL

# %%
#Hacer ejercicios 4, 5 y 6

# %%
# 1 - Importar las librerías necesarias para crear la conexión y trabajar con Pandas.

import mysql.connector
from mysql.connector import errorcode
import pandas as pd

# %%
# 2 Crear la conexión a la base de datos Northwind que devuelva un mensaje de error si algo no ocurre cómo debería.

configuracion = {
    'user': 'root',         
    'password': 'AlumnaAdalab',    
    'host': '127.0.0.1',           
    'database': 'northwind'  
}

conexion = mysql.connector.connect(**configuracion)

try:
  conexion 

except mysql.connector.Error as err:

  # si es un error con la contraseña devuelveme un mensaje de acceso denegado ya que tenemos problemas con la contraseña
  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  
  # si el error no tiene que ver con la contraseña, puede ser porque la base de datos no exista, devuelveme un mensaje de que la base de datos no existe
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  
  # si no es por ninguno de los errores anteriores, printeame cual es el error que estoy teniendo en mi conexión
  else:
    print(err)

# %%
# 3 Usando "information_schema", extraer los nombres de las columnas de la tabla "customers" de la BBDD "northwind" // Dijo que de este ejercicio podemos pasar y que luego lo explica

# %%
# 4 Seleccionar todo de la tabla "customers" donde "country" sea "USA" o "Germany". Almacenar los resultados en una variable.

# iniciamos el cursor
cursor = conexion.cursor()

# ejecutamos nuestra query
cursor.execute("SELECT * FROM customers")

# le decimos que nos devuelva todos los resultados y los almacenamos en una variable llamada myresult
result = cursor.fetchall()

# %%
# 5 Convertir los resultados del ejercicio anterior en un Dataframe (no od olvidéis de poner el nombre a las columnas en el orden correcto).
df_customers = pd.DataFrame(result,columns=['customer_id', 'company_name', 'contact_name', 'contact_title', 'address', 'city', 'region', 'postal_code', 'country', 'phone', 'fax'])
df_customers
# Out:
#    customer_id                        company_name             contact_name  \
# 0        ALFKI                 Alfreds Futterkiste             Maria Anders
# 1        ANATR  Ana Trujillo Emparedados y helados             Ana Trujillo
# 2        ANTON             Antonio Moreno Taquer?a           Antonio Moreno
# 3        AROUT                     Around the Horn             Thomas Hardy
# 4        BERGS                  Berglunds snabbk?p       Christina Berglund
# ..         ...                                 ...                      ...
# 86       WARTH                      Wartian Herkku         Pirkko Koskitalo
# 87       WELLI              Wellington Importadora            Paula Parente
# 88       WHITC                White Clover Markets           Karl Jablonski
# 89       WILMK                         Wilman Kala          Matti Karttunen
# 90       WOLZA                      Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
#                 contact_title                        address         city  \
# 0        Sales Representative                  Obere Str. 57       Berlin
# 1                       Owner  Avda. de la Constituci?n 2222  M?xico D.F.
# 2                       Owner                Mataderos  2312  M?xico D.F.
# 3        Sales Representative                120 Hanover Sq.       London
# 4         Order Administrator                Berguvsv?gen  8        Lule?
# ..                        ...                            ...          ...
# 86         Accounting Manager                    Torikatu 38         Oulu
# 87              Sales Manager             Rua do Mercado, 12      Resende
# 88                      Owner    305 - 14th Ave. S. Suite 3B      Seattle
# 89  Owner/Marketing Assistant                  Keskuskatu 45     Helsinki
# 90                      Owner                ul. Filtrowa 68     Warszawa
#
#    region postal_code  country           phone             fax
# 0               12209  Germany     030-0074321     030-0076545
# 1               05021   Mexico    (5) 555-4729    (5) 555-3745
# 2               05023   Mexico    (5) 555-3932
# 3             WA1 1DP       UK  (171) 555-7788  (171) 555-6750
# 4            S-958 22   Sweden   0921-12 34 65   0921-12 34 67
# ..    ...         ...      ...             ...             ...
# 86              90110  Finland      981-443655      981-443655
# 87     SP   08737-363   Brazil   (14) 555-8122
# 88     WA       98128      USA  (206) 555-4112  (206) 555-4115
# 89              21240  Finland     90-224 8858     90-224 8858
# 90             01-012   Poland   (26) 642-7012   (26) 642-7012
#
# [91 rows x 11 columns]

# %%
# 6 Muestrar las 10 primeras filas del Dataframe y las 10 últimas.

df_customers.head(10)
# Out:
#   customer_id                        company_name        contact_name  \
# 0       ALFKI                 Alfreds Futterkiste        Maria Anders
# 1       ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2       ANTON             Antonio Moreno Taquer?a      Antonio Moreno
# 3       AROUT                     Around the Horn        Thomas Hardy
# 4       BERGS                  Berglunds snabbk?p  Christina Berglund
# 5       BLAUS             Blauer See Delikatessen          Hanna Moos
# 6       BLONP            Blondesddsl p?re et fils  Fr?d?rique Citeaux
# 7       BOLID           B?lido Comidas preparadas       Mart?n Sommer
# 8       BONAP                            Bon app'    Laurence Lebihan
# 9       BOTTM               Bottom-Dollar Markets   Elizabeth Lincoln
#
#           contact_title                        address         city region  \
# 0  Sales Representative                  Obere Str. 57       Berlin
# 1                 Owner  Avda. de la Constituci?n 2222  M?xico D.F.
# 2                 Owner                Mataderos  2312  M?xico D.F.
# 3  Sales Representative                120 Hanover Sq.       London
# 4   Order Administrator                Berguvsv?gen  8        Lule?
# 5  Sales Representative                 Forsterstr. 57     Mannheim
# 6     Marketing Manager               24, place Kl?ber   Strasbourg
# 7                 Owner                 C/ Araquil, 67       Madrid
# 8                 Owner           12, rue des Bouchers    Marseille
# 9    Accounting Manager             23 Tsawassen Blvd.    Tsawassen     BC
#
#   postal_code  country           phone             fax
# 0       12209  Germany     030-0074321     030-0076545
# 1       05021   Mexico    (5) 555-4729    (5) 555-3745
# 2       05023   Mexico    (5) 555-3932
# 3     WA1 1DP       UK  (171) 555-7788  (171) 555-6750
# 4    S-958 22   Sweden   0921-12 34 65   0921-12 34 67
# 5       68306  Germany      0621-08460      0621-08924
# 6       67000   France     88.60.15.31     88.60.15.32
# 7       28023    Spain  (91) 555 22 82  (91) 555 91 99
# 8       13008   France     91.24.45.40     91.24.45.41
# 9     T2F 8M4   Canada  (604) 555-4729  (604) 555-3745

# %%
df_customers.tail(10)
# Out:
#    customer_id                       company_name             contact_name  \
# 81       TRAIH  Trail's Head Gourmet Provisioners           Helvetius Nagy
# 82       VAFFE                       Vaffeljernet              Palle Ibsen
# 83       VICTE               Victuailles en stock             Mary Saveley
# 84       VINET          Vins et alcools Chevalier             Paul Henriot
# 85       WANDK                  Die Wandernde Kuh              Rita M?ller
# 86       WARTH                     Wartian Herkku         Pirkko Koskitalo
# 87       WELLI             Wellington Importadora            Paula Parente
# 88       WHITC               White Clover Markets           Karl Jablonski
# 89       WILMK                        Wilman Kala          Matti Karttunen
# 90       WOLZA                     Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
#                 contact_title                      address       city region  \
# 81            Sales Associate            722 DaVinci Blvd.   Kirkland     WA
# 82              Sales Manager                Smagsloget 45      ?rhus
# 83                Sales Agent           2, rue du Commerce       Lyon
# 84         Accounting Manager           59 rue de l'Abbaye      Reims
# 85       Sales Representative            Adenauerallee 900  Stuttgart
# 86         Accounting Manager                  Torikatu 38       Oulu
# 87              Sales Manager           Rua do Mercado, 12    Resende     SP
# 88                      Owner  305 - 14th Ave. S. Suite 3B    Seattle     WA
# 89  Owner/Marketing Assistant                Keskuskatu 45   Helsinki
# 90                      Owner              ul. Filtrowa 68   Warszawa
#
#    postal_code  country           phone             fax
# 81       98034      USA  (206) 555-8257  (206) 555-2174
# 82        8200  Denmark     86 21 32 43     86 22 33 44
# 83       69004   France     78.32.54.86     78.32.54.87
# 84       51100   France     26.47.15.10     26.47.15.11
# 85       70563  Germany     0711-020361     0711-035428
# 86       90110  Finland      981-443655      981-443655
# 87   08737-363   Brazil   (14) 555-8122
# 88       98128      USA  (206) 555-4112  (206) 555-4115
# 89       21240  Finland     90-224 8858     90-224 8858
# 90      01-012   Poland   (26) 642-7012   (26) 642-7012

# %%
# 7 Mostrar 5 filas aleatorias del Dataframe.

df_customers.sample(5)
# Out:
#    customer_id          company_name     contact_name        contact_title  \
# 88       WHITC  White Clover Markets   Karl Jablonski                Owner
# 38       KOENE       K?niglich Essen    Philip Cramer      Sales Associate
# 50       MEREP        M?re Paillarde   Jean Fresni?re  Marketing Assistant
# 45       LILAS     LILA-Supermercado  Carlos Gonz?lez   Accounting Manager
# 40       LAMAI      La maison d'Asie   Annette Roulet        Sales Manager
#
#                                            address          city  region  \
# 88                     305 - 14th Ave. S. Suite 3B       Seattle      WA
# 38                                   Maubelstr. 90   Brandenburg
# 50                              43 rue St. Laurent      Montr?al  Qu?bec
# 45  Carrera 52 con Ave. Bol?var #65-98 Llano Largo  Barquisimeto    Lara
# 40                           1 rue Alsace-Lorraine      Toulouse
#
#    postal_code    country           phone             fax
# 88       98128        USA  (206) 555-4112  (206) 555-4115
# 38       14776    Germany      0555-09876
# 50     H1J 1C3     Canada  (514) 555-8054  (514) 555-8055
# 45        3508  Venezuela    (9) 331-6954    (9) 331-7256
# 40       31000     France     61.77.61.10     61.77.61.11

# %%
# 8 ¿Hay nulos en el Dataframe? El resultado debe verse para cada una de las columnas.

df_customers.isnull().sum()
# Out:
# customer_id      0
# company_name     0
# contact_name     0
# contact_title    0
# address          0
# city             0
# region           0
# postal_code      0
# country          0
# phone            0
# fax              0
# dtype: int64

# %%
# 9 Mostrar los principales estadísticos.

df_customers.describe()
# Out:
#        customer_id         company_name  contact_name         contact_title  \
# count           91                   91            91                    91
# unique          91                   91            91                    12
# top          ALFKI  Alfreds Futterkiste  Maria Anders  Sales Representative
# freq             1                    1             1                    17
#
#               address    city region postal_code country        phone fax
# count              91      91     91          91      91           91  91
# unique             91      69     19          87      21           91  70
# top     Obere Str. 57  London               1010     USA  030-0074321
# freq                1       6     60           3      13            1  22

# %%
# 10 Mostrar el nombre de las columnas del Dataframe.

df_customers.columns
# Out:
# Index(['customer_id', 'company_name', 'contact_name', 'contact_title',
#        'address', 'city', 'region', 'postal_code', 'country', 'phone', 'fax'],
#       dtype='object')
