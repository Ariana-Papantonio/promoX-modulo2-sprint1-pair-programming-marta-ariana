# %%
import pandas as pd

import json

# %%
import xml.etree.ElementTree as ET

# %%
df_videogames= pd.read_csv("videogames.csv") #abrimos el archivo csv

# %%
df_videogames.head()
# Out:
#    Unnamed: 0                        name  \
# 0           0                  Spider-Man
# 1           1      Red Dead Redemption II
# 2           2          Grand Theft Auto V
# 3           3                  God of War
# 4           4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# ...

# %%
df_videogames = pd.read_csv("videogames.csv", index_col = 0) #lo abrimos en lectura sin la primera columna

# %%
df_videogames.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %%
df_videogames.to_excel("videogames.xlsx") #lo convertimos a excel

# %%
df_videogames_excel = pd.read_excel("videogames.xlsx", index_col = 0)

# %%
df_videogames_excel.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %%
df_videogames.to_csv("files/videogames.csv")

# %%
with open("files/personal.json", "r") as fichero: # introducimos el nombre de nuestro archivo json y "r" porque lo vamos a leer(read)
    personal = json.load(fichero) #lo igualamos a una variable para tenerlo almacenado

# %%
type(personal)
# Out:
# dict

# %%
personal
# Out:
# {'workers': [{'nombre': 'Ana',
#    'edad': 34,
#    'experiencia': 5,
#    'nivel': 'Senior',
#    'salario': 50000,
#    'mascota': 'gatos'},
#   {'nombre': 'Eva',
#    'edad': 37,
#    'experiencia': 2,
#    'nivel': 'Mid',
#    'salario': 35000},
#   {'nombre': 'Marta',
#    'edad': 27,
#    'experiencia': 1,
#    'nivel': 'Junior',
#    'salario': 25000},
#   {'nombre': 'Paula',
#    'edad': 30,
#    'experiencia': 3,
#    'nivel': 'Mid',
#    'salario': 35000}]}

# %%
len(personal["workers"])
# Out:
# 4

# %%
personal["workers"]
# Out:
# [{'nombre': 'Ana',
#   'edad': 34,
#   'experiencia': 5,
#   'nivel': 'Senior',
#   'salario': 50000,
#   'mascota': 'gatos'},
#  {'nombre': 'Eva',
#   'edad': 37,
#   'experiencia': 2,
#   'nivel': 'Mid',
#   'salario': 35000},
#  {'nombre': 'Marta',
#   'edad': 27,
#   'experiencia': 1,
#   'nivel': 'Junior',
#   'salario': 25000},
#  {'nombre': 'Paula',
#   'edad': 30,
#   'experiencia': 3,
#   'nivel': 'Mid',
#   'salario': 35000}]

# %%
with open("personal.json", "w") as fichero: #guardamos el fichero en un nuevo json. usamos "w" para escribir write
    json.dump(personal, fichero)

# %%
pd.read_json("personal.json")
# Out:
#                                              workers
# 0  {'nombre': 'Ana', 'edad': 34, 'experiencia': 5...
# 1  {'nombre': 'Eva', 'edad': 37, 'experiencia': 2...
# 2  {'nombre': 'Marta', 'edad': 27, 'experiencia':...
# 3  {'nombre': 'Paula', 'edad': 30, 'experiencia':...
